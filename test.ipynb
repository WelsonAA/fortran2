# %%
# !python.exe -m pip install --upgrade pip
# !pip install visual-automata
from automata.fa.dfa import DFA

# %%
from visual_automata.fa.dfa import VisualDFA
dfa = VisualDFA(
    states={"q0", "q1", "q2", "q3", "q4"},
    input_symbols={"0", "1"},
    transitions={
        "q0": {"0": "q3", "1": "q1"},
        "q1": {"0": "q3", "1": "q2"},
        "q2": {"0": "q3", "1": "q2"},
        "q3": {"0": "q4", "1": "q1"},
        "q4": {"0": "q4", "1": "q1"},
    },
    initial_state="q0",
    final_states={"q2", "q4"},
)
dfa = VisualDFA(dfa)
dfa.table
dfa.show_diagram()

# %%
import graphviz

dot = graphviz.Digraph()

dot.node('start', shape='circle', fillcolor='green')
dot.node('1', shape='circle', fillcolor='lightblue')
dot.node('2', shape='circle', fillcolor='lightblue')
dot.node('3', shape='circle', fillcolor='lightblue')
dot.node('4', shape='circle', fillcolor='lightblue')
dot.node('5', shape='circle', fillcolor='lightblue')
dot.node('6', shape='circle', fillcolor='lightblue')
dot.node('7', shape='doublecircle', fillcolor='green')

dot.node('8', shape='circle', fillcolor='lightblue')
dot.node('9', shape='circle', fillcolor='lightblue')
dot.node('10', shape='circle', fillcolor='lightblue')
dot.node('11', shape='circle', fillcolor='lightblue')
dot.node('12', shape='circle', fillcolor='lightblue')
dot.node('13', shape='doublecircle', fillcolor='green')

dot.node('16', shape='circle', fillcolor='lightblue')
dot.node('17', shape='circle', fillcolor='lightblue')
dot.node('18', shape='circle', fillcolor='lightblue')
dot.node('19', shape='circle', fillcolor='lightblue')
dot.node('20', shape='circle', fillcolor='lightblue')
dot.node('21', shape='circle', fillcolor='lightblue')
dot.node('22', shape='circle', fillcolor='lightblue')
dot.node('23', shape='circle', fillcolor='lightblue')
dot.node('24', shape='doublecircle', fillcolor='green')

dot.node('error', shape='doublecircle', fillcolor='red')

dot.edge('start', 'final1', label='[0-9]')
dot.edge('start', '1', label='L')
dot.edge('1', '2', label='O')
dot.edge('2', '3', label='G')
dot.edge('3', '4', label='I')
dot.edge('4', '5', label='C')
dot.edge('5', '6', label='A')
dot.edge('6', '7', label='L')

dot.edge('start', '8', label='.')
dot.edge('8', '9', label='F')
dot.edge('9', '10', label='A')
dot.edge('10', '11', label='L')
dot.edge('11', '12', label='S')
dot.edge('12', '13', label='E')

dot.edge('start', '16', label='C')
dot.edge('16', '17', label='H')
dot.edge('17', '18', label='A')
dot.edge('18', '19', label='R')
dot.edge('19', '20', label='A')
dot.edge('20', '21', label='C')
dot.edge('21', '22', label='T')
dot.edge('22', '23', label='E')
dot.edge('23', '24', label='R')

dot.render('graph_output', format='png', view=True)
# Out:
# 'graph_output.png'

# %%
# !pip install matplotlib
# Out:
# ...
#   Using cached matplotlib-3.7.1-cp39-cp39-win_amd64.whl (7.6 MB)
# ...
#   Using cached contourpy-1.0.7-cp39-cp39-win_amd64.whl (160 kB)
# ...
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# ...
#                                               0.0/1.0 MB ? eta -:--:--
#      -                                        0.0/1.0 MB 1.4 MB/s eta 0:00:01
#      ---                                      0.1/1.0 MB 770.8 kB/s eta 0:00:02
#      ----                                     0.1/1.0 MB 731.4 kB/s eta 0:00:02
#      --------                                 0.2/1.0 MB 1.1 MB/s eta 0:00:01
#      ----------                               0.3/1.0 MB 1.1 MB/s eta 0:00:01
#      ----------                               0.3/1.0 MB 1.1 MB/s eta 0:00:01
#      ----------                               0.3/1.0 MB 1.1 MB/s eta 0:00:01
#      --------------------                     0.5/1.0 MB 1.5 MB/s eta 0:00:01
#      ---------------------                    0.5/1.0 MB 1.2 MB/s eta 0:00:01
# ...

# %%
import graphviz

dot = graphviz.Digraph()
dot.graph_attr['layout'] = 'dot'
dot.graph_attr['rankdir']='LR'
dot.node('start', shape='circle', fillcolor='green')
dot.node('1', shape='circle', fillcolor='lightblue')
dot.node('2', shape='circle', fillcolor='lightblue')
dot.node('3', shape='circle', fillcolor='lightblue')
dot.node('4', shape='circle', fillcolor='lightblue')
dot.node('5', shape='circle', fillcolor='lightblue')
dot.node('6', shape='circle', fillcolor='lightblue')
dot.node('7', shape='doublecircle', fillcolor='green')

dot.node('8', shape='circle', fillcolor='lightblue')
dot.node('9', shape='circle', fillcolor='lightblue')
dot.node('10', shape='circle', fillcolor='lightblue')
dot.node('11', shape='circle', fillcolor='lightblue')
dot.node('12', shape='circle', fillcolor='lightblue')
dot.node('13', shape='circle', fillcolor='lightblue')
dot.node('14', shape='doublecircle', fillcolor='green')

dot.node('16', shape='circle', fillcolor='lightblue')
dot.node('17', shape='circle', fillcolor='lightblue')
dot.node('18', shape='circle', fillcolor='lightblue')
dot.node('19', shape='circle', fillcolor='lightblue')
dot.node('20', shape='circle', fillcolor='lightblue')
dot.node('21', shape='circle', fillcolor='lightblue')
dot.node('22', shape='circle', fillcolor='lightblue')
dot.node('23', shape='circle', fillcolor='lightblue')
dot.node('24', shape='doublecircle', fillcolor='green')

dot.node('25', shape='circle', fillcolor='lightblue')
dot.node('26', shape='circle', fillcolor='lightblue')
dot.node('27', shape='circle', fillcolor='lightblue')
dot.node('28', shape='circle', fillcolor='lightblue')
dot.node('29', shape='circle', fillcolor='lightblue')
dot.node('30', shape='doublecircle', fillcolor='green')

dot.node('31', shape='circle', fillcolor='lightblue')
dot.node('32', shape='circle', fillcolor='lightblue')
dot.node('33', shape='circle', fillcolor='lightblue')
dot.node('34', shape='circle', fillcolor='lightblue')
dot.node('35', shape='circle', fillcolor='lightblue')

dot.node('36', shape='doublecircle', fillcolor='green')

dot.node('40', shape='doublecircle', fillcolor='green')
dot.node('41', shape='doublecircle', fillcolor='green')
dot.node('42', shape='circle', fillcolor='lightblue')
dot.node('43', shape='circle', fillcolor='lightblue')
dot.node('44', shape='circle', fillcolor='lightblue')
dot.node('45', shape='circle', fillcolor='lightblue')
dot.node('47', shape='circle', fillcolor='lightblue')
dot.node('48', shape='circle', fillcolor='lightblue')
dot.node('49', shape='circle', fillcolor='lightblue')
dot.node('50', shape='circle', fillcolor='lightblue')
dot.node('51', shape='circle', fillcolor='lightblue')
dot.node('52', shape='circle', fillcolor='lightblue')
dot.node('53', shape='circle', fillcolor='lightblue')

dot.node('55', shape='circle', fillcolor='lightblue')
dot.node('56', shape='circle', fillcolor='lightblue')
dot.node('57', shape='circle', fillcolor='lightblue')
dot.node('58', shape='circle', fillcolor='lightblue')

dot.node('60', shape='circle', fillcolor='lightblue')
dot.node('61', shape='circle', fillcolor='lightblue')
dot.node('62', shape='circle', fillcolor='lightblue')
dot.node('63', shape='circle', fillcolor='lightblue')

dot.node('64', shape='circle', fillcolor='lightblue')
dot.node('65', shape='circle', fillcolor='lightblue')
dot.node('66', shape='circle', fillcolor='lightblue')
dot.node('67', shape='doublecircle', fillcolor='green')

dot.node('68', shape='circle', fillcolor='lightblue')
dot.node('69', shape='circle', fillcolor='lightblue')
dot.node('70', shape='circle', fillcolor='lightblue')
dot.node('71', shape='doublecircle', fillcolor='green')

dot.node('72', shape='circle', fillcolor='lightblue')
dot.node('73', shape='circle', fillcolor='lightblue')
dot.node('74', shape='circle', fillcolor='lightblue')
dot.node('75', shape='circle', fillcolor='lightblue')
dot.node('76', shape='circle', fillcolor='lightblue')
dot.node('77', shape='circle', fillcolor='lightblue')
dot.node('78', shape='circle', fillcolor='lightblue')
dot.node('79', shape='doublecircle', fillcolor='green')
dot.node('80', shape='circle', fillcolor='lightblue')
dot.node('81', shape='circle', fillcolor='lightblue')
dot.node('82', shape='circle', fillcolor='lightblue')
dot.node('83', shape='circle', fillcolor='lightblue')
dot.node('84', shape='circle', fillcolor='lightblue')
dot.node('85', shape='doublecircle', fillcolor='green')

dot.node('54', shape='doublecircle', fillcolor='green')

dot.node('46', shape='doublecircle', fillcolor='green')

dot.node('59', shape='doublecircle', fillcolor='green')

dot.node('error', shape='doublecircle', fillcolor='red')

dot.edge('start', '1', label='L')
dot.edge('1', '2', label='O')
dot.edge('2', '3', label='G')
dot.edge('3', '4', label='I')
dot.edge('4', '5', label='C')
dot.edge('5', '6', label='A')
dot.edge('6', '7', label='L')

dot.edge('start', '31', label='E')
dot.edge('31', '32', label='N')
dot.edge('32', '33', label='D')

dot.edge('31', '34', label='L')
dot.edge('34', '35', label='S')
dot.edge('35', '36', label='E')

dot.edge('16', '25', label='O')
dot.edge('25', '26', label='M')
dot.edge('26', '27', label='P')
dot.edge('27', '28', label='L')
dot.edge('28', '29', label='E')
dot.edge('29', '30', label='X')

dot.edge('start', '8', label=' . ')
dot.edge('8', '9', label='F')

dot.edge('8', '60', label='T')
dot.edge('60', '61', label='R')
dot.edge('61', '62', label='U')
dot.edge('62', '63', label='E')
dot.edge('63', '13', label='')

dot.edge('9', '10', label='A')
dot.edge('10', '11', label='L')
dot.edge('11', '12', label='S')
dot.edge('12', '13', label='E')
dot.edge('13', '14', label=' . ')

dot.edge('start', '37', label='R')
dot.edge('37', '38', label='E')
dot.edge('38', '39', label='A')
dot.edge('39', '40', label='L')

dot.edge('39', '41', label='D')

dot.edge('start', '16', label='C')
dot.edge('16', '17', label='H')
dot.edge('17', '18', label='A')
dot.edge('18', '19', label='R')
dot.edge('19', '20', label='A')
dot.edge('20', '21', label='C')
dot.edge('21', '22', label='T')
dot.edge('22', '23', label='E')
dot.edge('23', '24', label='R')

dot.edge('start', '68', label='N')
dot.edge('68', '69', label='O')

dot.edge('start', '72', label='I')
dot.edge('72', '73', label='M')
dot.edge('73', '74', label='P')
dot.edge('74', '75', label='L')
dot.edge('75', '76', label='I')
dot.edge('76', '77', label='C')
dot.edge('77', '78', label='I')
dot.edge('78', '79', label='T')

dot.edge('72', '80', label='N')
dot.edge('80', '81', label='T')
dot.edge('81', '82', label='E')
dot.edge('82', '83', label='G')
dot.edge('83', '84', label='E')
dot.edge('84', '85', label='R')

dot.edge('start', '42', label='P')
dot.edge('42', '43', label='R')

dot.edge('43', '55', label='O')
dot.edge('55', '56', label='G')
dot.edge('56', '57', label='R')
dot.edge('57', '58', label='A')
dot.edge('58', '59', label='M')

dot.edge('43', '44', label='I')
dot.edge('44', '45', label='N')
dot.edge('45', '46', label='T')
dot.edge('42', '47', label='A')
dot.edge('47', '48', label='R')
dot.edge('48', '49', label='A')
dot.edge('49', '50', label='M')
dot.edge('50', '51', label='E')
dot.edge('51', '52', label='T')
dot.edge('52', '53', label='E')
dot.edge('53', '54', label='R')

dot.render('graph',format='png')

# %%
import graphviz

def generate_dfa(lex):
    identifier_dfa = graphviz.Digraph(comment='DFA for Identifier')

    identifier_dfa.node('start')
    identifier_dfa.node('accept', shape='doublecircle')

    input_word = lex
    a=1
    current_node = 'start'
    for node_count, char in enumerate(input_word):
        next_node = f'node{node_count}'
        identifier_dfa.node(next_node, label=a)
        identifier_dfa.edge(current_node, next_node, label=char)
        current_node = next_node
        a=a+1

    identifier_dfa.edge(current_node, 'accept', label='')

    identifier_dfa.attr(rankdir='LR')

    identifier_dfa.render('identifier', format='png', view=True, directory="DFA")

generate_dfa("LOGICAL")
